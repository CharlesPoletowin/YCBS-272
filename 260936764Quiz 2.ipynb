# %% [markdown]
# # Quiz #2
#
#
# 1.   All questions contain equal marks [1 point].
# 2.   Import libraries as per your need.
#
# 1.   You are not allowed to google any queries during the duration of the quiz.
# 2.   However, you are free to use the inbuilt help/ function descriptor of colab [using TAB key]
#
#
#
#
# Save the file as 'XXXXXXXX.ipynb'. Replace X with your McGill Id.
#
# Go to [File] -> [print] OR [File] -> [Download .ipynb]
#
#  and mail it to arbaaz.khan@mail.mcgill.ca

# %% [markdown]
# **Name:** Chuanyu Zhou
#
# **McGill Id:** 260936764

# %% [markdown]
# ## Loading data

# %%
import numpy as np

n = 200

# linespace produces equi-distant x values for, is useful for plotting curves
x = np.linspace(0.0, 2.0, n)

# initiate parameters as a habit
mu, sigma = 0, 50

#set seeed to regenerate the same random numbers, 
#useful for reproducible results.
np.random.seed(1)


e = np.random.normal(loc=mu, scale= sigma, size=len(x))

y = np.exp(3*x)+e

# %% [markdown]
# ## 1. Generate the scatter plot between 'x' & 'y'. Superimpose the plot with a line plot, such that you get the following figure.
#
# Hint 1: Generate the line plot by removing 'e' component from 'y'
#
# The color and line style can vary.!
#
# [Hint 2](https://drive.google.com/open?id=1J2ipfAlbPykNFrqiroAX3lz_JRybTbqv)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Set up figure size and DPI for screen demo
plt.rcParams['figure.figsize'] = (4,3)
plt.rcParams['figure.dpi'] = 150

# %%
plt.scatter(x,y)
plt.plot(x,y-e,'r')

# %%
! git clone https://github.com/arbi11/YCBS-272.git
! ls
# Out:
# Cloning into 'YCBS-272'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 75 (delta 33), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (75/75), done.
# sample_data  YCBS-272

# %%
cd YCBS-272/
# Out:
# /content/YCBS-272

# %%
! ls
# Out:
# Advertising.csv		       Lec_4_2.ipynb	   Lec_6_decision_trees.ipynb
# drinks.csv		       Lec_4_3.ipynb	   nhanes_2015_2016.csv
# fandango_score_comparison.csv  Lec_4_4.ipynb	   Quiz_2.ipynb
# Lec_2.ipynb		       Lec_4_5.ipynb	   README.md
# Lec_2_solution.ipynb	       Lec_4_6.ipynb	   spamdata.csv
# Lec_4_1.ipynb		       Lec_5_Lesson.ipynb  YCBS_272_Assignment_1.ipynb

# %% [markdown]
# # Importing Data

# %%
import pandas as pd
advertising = pd.read_csv('Advertising.csv', usecols=[2,3,4])
advertising.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
# radio        200 non-null float64
# newspaper    200 non-null float64
# sales        200 non-null float64
# dtypes: float64(3)
# memory usage: 4.8 KB

# %% [markdown]
# # 2. Extract just the values of the dataframe
#
# Hint: you will get back a numpy array

# %%
np.array(advertising)
# Out:
# array([[ 37.8,  69.2,  22.1],
#        [ 39.3,  45.1,  10.4],
#        [ 45.9,  69.3,   9.3],
#        [ 41.3,  58.5,  18.5],
#        [ 10.8,  58.4,  12.9],
#        [ 48.9,  75. ,   7.2],
#        [ 32.8,  23.5,  11.8],
#        [ 19.6,  11.6,  13.2],
#        [  2.1,   1. ,   4.8],
#        [  2.6,  21.2,  10.6],
#        [  5.8,  24.2,   8.6],
#        [ 24. ,   4. ,  17.4],
#        [ 35.1,  65.9,   9.2],
#        [  7.6,   7.2,   9.7],
#        [ 32.9,  46. ,  19. ],
#        [ 47.7,  52.9,  22.4],
#        [ 36.6, 114. ,  12.5],
#        [ 39.6,  55.8,  24.4],
#        [ 20.5,  18.3,  11.3],
#        [ 23.9,  19.1,  14.6],
#        [ 27.7,  53.4,  18. ],
#        [  5.1,  23.5,  12.5],
#        [ 15.9,  49.6,   5.6],
#        [ 16.9,  26.2,  15.5],
#        [ 12.6,  18.3,   9.7],
#        [  3.5,  19.5,  12. ],
#        [ 29.3,  12.6,  15. ],
#        [ 16.7,  22.9,  15.9],
#        [ 27.1,  22.9,  18.9],
#        [ 16. ,  40.8,  10.5],
#        [ 28.3,  43.2,  21.4],
#        [ 17.4,  38.6,  11.9],
#        [  1.5,  30. ,   9.6],
#        [ 20. ,   0.3,  17.4],
#        [  1.4,   7.4,   9.5],
#        [  4.1,   8.5,  12.8],
#        [ 43.8,   5. ,  25.4],
#        [ 49.4,  45.7,  14.7],
#        [ 26.7,  35.1,  10.1],
#        [ 37.7,  32. ,  21.5],
#        [ 22.3,  31.6,  16.6],
#        [ 33.4,  38.7,  17.1],
#        [ 27.7,   1.8,  20.7],
#        [  8.4,  26.4,  12.9],
#        [ 25.7,  43.3,   8.5],
#        [ 22.5,  31.5,  14.9],
#        [  9.9,  35.7,  10.6],
#        [ 41.5,  18.5,  23.2],
#        [ 15.8,  49.9,  14.8],
#        [ 11.7,  36.8,   9.7],
#        [  3.1,  34.6,  11.4],
#        [  9.6,   3.6,  10.7],
#        [ 41.7,  39.6,  22.6],
#        [ 46.2,  58.7,  21.2],
#        [ 28.8,  15.9,  20.2],
#        [ 49.4,  60. ,  23.7],
#        [ 28.1,  41.4,   5.5],
#        [ 19.2,  16.6,  13.2],
#        [ 49.6,  37.7,  23.8],
#        [ 29.5,   9.3,  18.4],
#        [  2. ,  21.4,   8.1],
#        [ 42.7,  54.7,  24.2],
#        [ 15.5,  27.3,  15.7],
#        [ 29.6,   8.4,  14. ],
#        [ 42.8,  28.9,  18. ],
#        [  9.3,   0.9,   9.3],
#        [ 24.6,   2.2,   9.5],
#        [ 14.5,  10.2,  13.4],
#        [ 27.5,  11. ,  18.9],
#        [ 43.9,  27.2,  22.3],
#        [ 30.6,  38.7,  18.3],
#        [ 14.3,  31.7,  12.4],
#        [ 33. ,  19.3,   8.8],
#        [  5.7,  31.3,  11. ],
#        [ 24.6,  13.1,  17. ],
#        [ 43.7,  89.4,   8.7],
#        [  1.6,  20.7,   6.9],
#        [ 28.5,  14.2,  14.2],
#        [ 29.9,   9.4,   5.3],
#        [  7.7,  23.1,  11. ],
#        [ 26.7,  22.3,  11.8],
#        [  4.1,  36.9,  12.3],
#        [ 20.3,  32.5,  11.3],
#        [ 44.5,  35.6,  13.6],
#        [ 43. ,  33.8,  21.7],
#        [ 18.4,  65.7,  15.2],
#        [ 27.5,  16. ,  12. ],
#        [ 40.6,  63.2,  16. ],
#        [ 25.5,  73.4,  12.9],
#        [ 47.8,  51.4,  16.7],
#        [  4.9,   9.3,  11.2],
#        [  1.5,  33. ,   7.3],
#        [ 33.5,  59. ,  19.4],
#        [ 36.5,  72.3,  22.2],
#        [ 14. ,  10.9,  11.5],
#        [ 31.6,  52.9,  16.9],
#        [  3.5,   5.9,  11.7],
#        [ 21. ,  22. ,  15.5],
#        [ 42.3,  51.2,  25.4],
#        [ 41.7,  45.9,  17.2],
#        [  4.3,  49.8,  11.7],
#        [ 36.3, 100.9,  23.8],
#        [ 10.1,  21.4,  14.8],
#        [ 17.2,  17.9,  14.7],
#        [ 34.3,   5.3,  20.7],
#        [ 46.4,  59. ,  19.2],
#        [ 11. ,  29.7,   7.2],
#        [  0.3,  23.2,   8.7],
#        [  0.4,  25.6,   5.3],
#        [ 26.9,   5.5,  19.8],
#        [  8.2,  56.5,  13.4],
#        [ 38. ,  23.2,  21.8],
#        [ 15.4,   2.4,  14.1],
#        [ 20.6,  10.7,  15.9],
#        [ 46.8,  34.5,  14.6],
#        [ 35. ,  52.7,  12.6],
#        [ 14.3,  25.6,  12.2],
#        [  0.8,  14.8,   9.4],
#        [ 36.9,  79.2,  15.9],
#        [ 16. ,  22.3,   6.6],
#        [ 26.8,  46.2,  15.5],
#        [ 21.7,  50.4,   7. ],
#        [  2.4,  15.6,  11.6],
#        [ 34.6,  12.4,  15.2],
#        [ 32.3,  74.2,  19.7],
#        [ 11.8,  25.9,  10.6],
#        [ 38.9,  50.6,   6.6],
#        [  0. ,   9.2,   8.8],
#        [ 49. ,   3.2,  24.7],
#        [ 12. ,  43.1,   9.7],
#        [ 39.6,   8.7,   1.6],
#        [  2.9,  43. ,  12.7],
#        [ 27.2,   2.1,   5.7],
#        [ 33.5,  45.1,  19.6],
#        [ 38.6,  65.6,  10.8],
#        [ 47. ,   8.5,  11.6],
#        [ 39. ,   9.3,   9.5],
#        [ 28.9,  59.7,  20.8],
#        [ 25.9,  20.5,   9.6],
#        [ 43.9,   1.7,  20.7],
#        [ 17. ,  12.9,  10.9],
#        [ 35.4,  75.6,  19.2],
#        [ 33.2,  37.9,  20.1],
#        [  5.7,  34.4,  10.4],
#        [ 14.8,  38.9,  11.4],
#        [  1.9,   9. ,  10.3],
#        [  7.3,   8.7,  13.2],
#        [ 49. ,  44.3,  25.4],
#        [ 40.3,  11.9,  10.9],
#        [ 25.8,  20.6,  10.1],
#        [ 13.9,  37. ,  16.1],
#        [  8.4,  48.7,  11.6],
#        [ 23.3,  14.2,  16.6],
#        [ 39.7,  37.7,  19. ],
#        [ 21.1,   9.5,  15.6],
#        [ 11.6,   5.7,   3.2],
#        [ 43.5,  50.5,  15.3],
#        [  1.3,  24.3,  10.1],
#        [ 36.9,  45.2,   7.3],
#        [ 18.4,  34.6,  12.9],
#        [ 18.1,  30.7,  14.4],
#        [ 35.8,  49.3,  13.3],
#        [ 18.1,  25.6,  14.9],
#        [ 36.8,   7.4,  18. ],
#        [ 14.7,   5.4,  11.9],
#        [  3.4,  84.8,  11.9],
#        [ 37.6,  21.6,   8. ],
#        [  5.2,  19.4,  12.2],
#        [ 23.6,  57.6,  17.1],
#        [ 10.6,   6.4,  15. ],
#        [ 11.6,  18.4,   8.4],
#        [ 20.9,  47.4,  14.5],
#        [ 20.1,  17. ,   7.6],
#        [  7.1,  12.8,  11.7],
#        [  3.4,  13.1,  11.5],
#        [ 48.9,  41.8,  27. ],
#        [ 30.2,  20.3,  20.2],
#        [  7.8,  35.2,  11.7],
#        [  2.3,  23.7,  11.8],
#        [ 10. ,  17.6,  12.6],
#        [  2.6,   8.3,  10.5],
#        [  5.4,  27.4,  12.2],
#        [  5.7,  29.7,   8.7],
#        [ 43. ,  71.8,  26.2],
#        [ 21.3,  30. ,  17.6],
#        [ 45.1,  19.6,  22.6],
#        [  2.1,  26.6,  10.3],
#        [ 28.7,  18.2,  17.3],
#        [ 13.9,   3.7,  15.9],
#        [ 12.1,  23.4,   6.7],
#        [ 41.1,   5.8,  10.8],
#        [ 10.8,   6. ,   9.9],
#        [  4.1,  31.6,   5.9],
#        [ 42. ,   3.6,  19.6],
#        [ 35.6,   6. ,  17.3],
#        [  3.7,  13.8,   7.6],
#        [  4.9,   8.1,   9.7],
#        [  9.3,   6.4,  12.8],
#        [ 42. ,  66.2,  25.5],
#        [  8.6,   8.7,  13.4]])

# %%
advertising.values
# Out:
# array([[ 37.8,  69.2,  22.1],
#        [ 39.3,  45.1,  10.4],
#        [ 45.9,  69.3,   9.3],
#        [ 41.3,  58.5,  18.5],
#        [ 10.8,  58.4,  12.9],
#        [ 48.9,  75. ,   7.2],
#        [ 32.8,  23.5,  11.8],
#        [ 19.6,  11.6,  13.2],
#        [  2.1,   1. ,   4.8],
#        [  2.6,  21.2,  10.6],
#        [  5.8,  24.2,   8.6],
#        [ 24. ,   4. ,  17.4],
#        [ 35.1,  65.9,   9.2],
#        [  7.6,   7.2,   9.7],
#        [ 32.9,  46. ,  19. ],
#        [ 47.7,  52.9,  22.4],
#        [ 36.6, 114. ,  12.5],
#        [ 39.6,  55.8,  24.4],
#        [ 20.5,  18.3,  11.3],
#        [ 23.9,  19.1,  14.6],
#        [ 27.7,  53.4,  18. ],
#        [  5.1,  23.5,  12.5],
#        [ 15.9,  49.6,   5.6],
#        [ 16.9,  26.2,  15.5],
#        [ 12.6,  18.3,   9.7],
#        [  3.5,  19.5,  12. ],
#        [ 29.3,  12.6,  15. ],
#        [ 16.7,  22.9,  15.9],
#        [ 27.1,  22.9,  18.9],
#        [ 16. ,  40.8,  10.5],
#        [ 28.3,  43.2,  21.4],
#        [ 17.4,  38.6,  11.9],
#        [  1.5,  30. ,   9.6],
#        [ 20. ,   0.3,  17.4],
#        [  1.4,   7.4,   9.5],
#        [  4.1,   8.5,  12.8],
#        [ 43.8,   5. ,  25.4],
#        [ 49.4,  45.7,  14.7],
#        [ 26.7,  35.1,  10.1],
#        [ 37.7,  32. ,  21.5],
#        [ 22.3,  31.6,  16.6],
#        [ 33.4,  38.7,  17.1],
#        [ 27.7,   1.8,  20.7],
#        [  8.4,  26.4,  12.9],
#        [ 25.7,  43.3,   8.5],
#        [ 22.5,  31.5,  14.9],
#        [  9.9,  35.7,  10.6],
#        [ 41.5,  18.5,  23.2],
#        [ 15.8,  49.9,  14.8],
#        [ 11.7,  36.8,   9.7],
#        [  3.1,  34.6,  11.4],
#        [  9.6,   3.6,  10.7],
#        [ 41.7,  39.6,  22.6],
#        [ 46.2,  58.7,  21.2],
#        [ 28.8,  15.9,  20.2],
#        [ 49.4,  60. ,  23.7],
#        [ 28.1,  41.4,   5.5],
#        [ 19.2,  16.6,  13.2],
#        [ 49.6,  37.7,  23.8],
#        [ 29.5,   9.3,  18.4],
#        [  2. ,  21.4,   8.1],
#        [ 42.7,  54.7,  24.2],
#        [ 15.5,  27.3,  15.7],
#        [ 29.6,   8.4,  14. ],
#        [ 42.8,  28.9,  18. ],
#        [  9.3,   0.9,   9.3],
#        [ 24.6,   2.2,   9.5],
#        [ 14.5,  10.2,  13.4],
#        [ 27.5,  11. ,  18.9],
#        [ 43.9,  27.2,  22.3],
#        [ 30.6,  38.7,  18.3],
#        [ 14.3,  31.7,  12.4],
#        [ 33. ,  19.3,   8.8],
#        [  5.7,  31.3,  11. ],
#        [ 24.6,  13.1,  17. ],
#        [ 43.7,  89.4,   8.7],
#        [  1.6,  20.7,   6.9],
#        [ 28.5,  14.2,  14.2],
#        [ 29.9,   9.4,   5.3],
#        [  7.7,  23.1,  11. ],
#        [ 26.7,  22.3,  11.8],
#        [  4.1,  36.9,  12.3],
#        [ 20.3,  32.5,  11.3],
#        [ 44.5,  35.6,  13.6],
#        [ 43. ,  33.8,  21.7],
#        [ 18.4,  65.7,  15.2],
#        [ 27.5,  16. ,  12. ],
#        [ 40.6,  63.2,  16. ],
#        [ 25.5,  73.4,  12.9],
#        [ 47.8,  51.4,  16.7],
#        [  4.9,   9.3,  11.2],
#        [  1.5,  33. ,   7.3],
#        [ 33.5,  59. ,  19.4],
#        [ 36.5,  72.3,  22.2],
#        [ 14. ,  10.9,  11.5],
#        [ 31.6,  52.9,  16.9],
#        [  3.5,   5.9,  11.7],
#        [ 21. ,  22. ,  15.5],
#        [ 42.3,  51.2,  25.4],
#        [ 41.7,  45.9,  17.2],
#        [  4.3,  49.8,  11.7],
#        [ 36.3, 100.9,  23.8],
#        [ 10.1,  21.4,  14.8],
#        [ 17.2,  17.9,  14.7],
#        [ 34.3,   5.3,  20.7],
#        [ 46.4,  59. ,  19.2],
#        [ 11. ,  29.7,   7.2],
#        [  0.3,  23.2,   8.7],
#        [  0.4,  25.6,   5.3],
#        [ 26.9,   5.5,  19.8],
#        [  8.2,  56.5,  13.4],
#        [ 38. ,  23.2,  21.8],
#        [ 15.4,   2.4,  14.1],
#        [ 20.6,  10.7,  15.9],
#        [ 46.8,  34.5,  14.6],
#        [ 35. ,  52.7,  12.6],
#        [ 14.3,  25.6,  12.2],
#        [  0.8,  14.8,   9.4],
#        [ 36.9,  79.2,  15.9],
#        [ 16. ,  22.3,   6.6],
#        [ 26.8,  46.2,  15.5],
#        [ 21.7,  50.4,   7. ],
#        [  2.4,  15.6,  11.6],
#        [ 34.6,  12.4,  15.2],
#        [ 32.3,  74.2,  19.7],
#        [ 11.8,  25.9,  10.6],
#        [ 38.9,  50.6,   6.6],
#        [  0. ,   9.2,   8.8],
#        [ 49. ,   3.2,  24.7],
#        [ 12. ,  43.1,   9.7],
#        [ 39.6,   8.7,   1.6],
#        [  2.9,  43. ,  12.7],
#        [ 27.2,   2.1,   5.7],
#        [ 33.5,  45.1,  19.6],
#        [ 38.6,  65.6,  10.8],
#        [ 47. ,   8.5,  11.6],
#        [ 39. ,   9.3,   9.5],
#        [ 28.9,  59.7,  20.8],
#        [ 25.9,  20.5,   9.6],
#        [ 43.9,   1.7,  20.7],
#        [ 17. ,  12.9,  10.9],
#        [ 35.4,  75.6,  19.2],
#        [ 33.2,  37.9,  20.1],
#        [  5.7,  34.4,  10.4],
#        [ 14.8,  38.9,  11.4],
#        [  1.9,   9. ,  10.3],
#        [  7.3,   8.7,  13.2],
#        [ 49. ,  44.3,  25.4],
#        [ 40.3,  11.9,  10.9],
#        [ 25.8,  20.6,  10.1],
#        [ 13.9,  37. ,  16.1],
#        [  8.4,  48.7,  11.6],
#        [ 23.3,  14.2,  16.6],
#        [ 39.7,  37.7,  19. ],
#        [ 21.1,   9.5,  15.6],
#        [ 11.6,   5.7,   3.2],
#        [ 43.5,  50.5,  15.3],
#        [  1.3,  24.3,  10.1],
#        [ 36.9,  45.2,   7.3],
#        [ 18.4,  34.6,  12.9],
#        [ 18.1,  30.7,  14.4],
#        [ 35.8,  49.3,  13.3],
#        [ 18.1,  25.6,  14.9],
#        [ 36.8,   7.4,  18. ],
#        [ 14.7,   5.4,  11.9],
#        [  3.4,  84.8,  11.9],
#        [ 37.6,  21.6,   8. ],
#        [  5.2,  19.4,  12.2],
#        [ 23.6,  57.6,  17.1],
#        [ 10.6,   6.4,  15. ],
#        [ 11.6,  18.4,   8.4],
#        [ 20.9,  47.4,  14.5],
#        [ 20.1,  17. ,   7.6],
#        [  7.1,  12.8,  11.7],
#        [  3.4,  13.1,  11.5],
#        [ 48.9,  41.8,  27. ],
#        [ 30.2,  20.3,  20.2],
#        [  7.8,  35.2,  11.7],
#        [  2.3,  23.7,  11.8],
#        [ 10. ,  17.6,  12.6],
#        [  2.6,   8.3,  10.5],
#        [  5.4,  27.4,  12.2],
#        [  5.7,  29.7,   8.7],
#        [ 43. ,  71.8,  26.2],
#        [ 21.3,  30. ,  17.6],
#        [ 45.1,  19.6,  22.6],
#        [  2.1,  26.6,  10.3],
#        [ 28.7,  18.2,  17.3],
#        [ 13.9,   3.7,  15.9],
#        [ 12.1,  23.4,   6.7],
#        [ 41.1,   5.8,  10.8],
#        [ 10.8,   6. ,   9.9],
#        [  4.1,  31.6,   5.9],
#        [ 42. ,   3.6,  19.6],
#        [ 35.6,   6. ,  17.3],
#        [  3.7,  13.8,   7.6],
#        [  4.9,   8.1,   9.7],
#        [  9.3,   6.4,  12.8],
#        [ 42. ,  66.2,  25.5],
#        [  8.6,   8.7,  13.4]])

# %% [markdown]
# # 3. Call the column 'radio' from the dataset
#
# There are two ways of doing this. Give the code for both

# %%
advertising.columns
# Out:
# Index(['radio', 'newspaper', 'sales'], dtype='object')

# %%
advertising['radio']
# Out:
# 0      37.8
# 1      39.3
# 2      45.9
# 3      41.3
# 4      10.8
# 5      48.9
# 6      32.8
# 7      19.6
# 8       2.1
# 9       2.6
# 10      5.8
# 11     24.0
# 12     35.1
# 13      7.6
# 14     32.9
# 15     47.7
# 16     36.6
# 17     39.6
# 18     20.5
# 19     23.9
# 20     27.7
# 21      5.1
# 22     15.9
# 23     16.9
# 24     12.6
# 25      3.5
# 26     29.3
# 27     16.7
# 28     27.1
# 29     16.0
#        ...
# 170    11.6
# 171    20.9
# 172    20.1
# 173     7.1
# 174     3.4
# 175    48.9
# 176    30.2
# 177     7.8
# 178     2.3
# 179    10.0
# 180     2.6
# 181     5.4
# 182     5.7
# 183    43.0
# 184    21.3
# 185    45.1
# 186     2.1
# 187    28.7
# 188    13.9
# 189    12.1
# 190    41.1
# 191    10.8
# 192     4.1
# 193    42.0
# 194    35.6
# 195     3.7
# 196     4.9
# 197     9.3
# 198    42.0
# 199     8.6
# Name: radio, Length: 200, dtype: float64

# %%
advertising.radio
# Out:
# 0      37.8
# 1      39.3
# 2      45.9
# 3      41.3
# 4      10.8
# 5      48.9
# 6      32.8
# 7      19.6
# 8       2.1
# 9       2.6
# 10      5.8
# 11     24.0
# 12     35.1
# 13      7.6
# 14     32.9
# 15     47.7
# 16     36.6
# 17     39.6
# 18     20.5
# 19     23.9
# 20     27.7
# 21      5.1
# 22     15.9
# 23     16.9
# 24     12.6
# 25      3.5
# 26     29.3
# 27     16.7
# 28     27.1
# 29     16.0
#        ...
# 170    11.6
# 171    20.9
# 172    20.1
# 173     7.1
# 174     3.4
# 175    48.9
# 176    30.2
# 177     7.8
# 178     2.3
# 179    10.0
# 180     2.6
# 181     5.4
# 182     5.7
# 183    43.0
# 184    21.3
# 185    45.1
# 186     2.1
# 187    28.7
# 188    13.9
# 189    12.1
# 190    41.1
# 191    10.8
# 192     4.1
# 193    42.0
# 194    35.6
# 195     3.7
# 196     4.9
# 197     9.3
# 198    42.0
# 199     8.6
# Name: radio, Length: 200, dtype: float64

# %% [markdown]
# # 4. See head and tails of the dataframe

# %%
advertising.head()
# Out:
#    radio  newspaper  sales
# 0   37.8       69.2   22.1
# 1   39.3       45.1   10.4
# 2   45.9       69.3    9.3
# 3   41.3       58.5   18.5
# 4   10.8       58.4   12.9

# %%
advertising.tail()
# Out:
#      radio  newspaper  sales
# 195    3.7       13.8    7.6
# 196    4.9        8.1    9.7
# 197    9.3        6.4   12.8
# 198   42.0       66.2   25.5
# 199    8.6        8.7   13.4

# %% [markdown]
# # 5. Transpose your data

# %%
advertising.T
# Out:
#             0     1     2     3     4    ...   195  196   197   198   199
# radio      37.8  39.3  45.9  41.3  10.8  ...   3.7  4.9   9.3  42.0   8.6
# newspaper  69.2  45.1  69.3  58.5  58.4  ...  13.8  8.1   6.4  66.2   8.7
# sales      22.1  10.4   9.3  18.5  12.9  ...   7.6  9.7  12.8  25.5  13.4
#
# [3 rows x 200 columns]

# %% [markdown]
# # 6. Difference between .iloc & .loc
#
# Explain the difference in 1 point or 1 line and write a code to show the working for both
# [1 point]

# %% [markdown]
# iloc and loc is used for get the information by index.
# the number in iloc is the index number created by pandas automocatically,
# however the string in loc can be defined by us.
#
# the parameter in iloc could only be index number, and the parameter in loc could only be string.

# %%
advertising.iloc[0]
# Out:
# radio        37.8
# newspaper    69.2
# sales        22.1
# Name: 0, dtype: float64

# %% [markdown]
# # 7. Draw the histogram of all the columns

# %%
plt.hist(advertising.T)

plt.grid(True, linestyle='-.')

# %% [markdown]
# # 8. Draw a box plot of any/all columns

# %%
import seaborn as sns

# %%
advertising.columns
# Out:
# Index(['radio', 'newspaper', 'sales'], dtype='object')

# %%
sns.boxplot(advertising['radio'])

# %% [markdown]
# # 9. Draw a vertical histogram/boxplot

# %%
plt.hist(advertising.T,orientation='horizontal')
# Out:
# ([array([56., 44., 41., 45., 14.,  0.,  0.,  0.,  0.,  0.]),
#   array([46., 40., 36., 30., 22., 13.,  9.,  2.,  1.,  1.]),
#   array([ 67., 120.,  13.,   0.,   0.,   0.,   0.,   0.,   0.,   0.])],
#  array([  0. ,  11.4,  22.8,  34.2,  45.6,  57. ,  68.4,  79.8,  91.2,
#         102.6, 114. ]),
#  <a list of 3 Lists of Patches objects>)

# %% [markdown]
# # 10. Draw a scatter plot between the columns 'radio' & 'sales'

# %%
plt.scatter(advertising['radio'],advertising['sales'])

# %% [markdown]
# # 11. Plot the graph with all the scatter plots between all the possible combinations of variable

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(advertising['radio'],advertising['sales'],advertising['newspaper'])

# %% [markdown]
# # 12. Get the correlation values of all the columns

# %%
advertising['radio'].corr(advertising['sales'])
# Out:
# 0.5762225745710551

# %%
advertising['radio'].corr(advertising['newspaper'])
# Out:
# 0.3541037507611754

# %%
advertising['newspaper'].corr(advertising['sales'])
# Out:
# 0.22829902637616528

# %% [markdown]
# # 13. Get a kdeplot from seaborn of any 1 of the column

# %%
sns.kdeplot(advertising['sales'])

# %% [markdown]
# # 14. Generate Stacked histograms plot:
#
#
#
# [Hint](https://drive.google.com/open?id=17YDjxGuA31fik_WVmr4fzbpMfcOEGYNy)

# %%
plt.hist(advertising['sales'],advertising['radio'],advertising['newspaper'],stacked="True")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-4df68fd3ff04> in <module>()
# ----> 1 plt.hist(advertising['sales'],advertising['radio'],advertising['newspaper'],stacked="True")
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2657         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2658         color=color, label=label, stacked=stacked, normed=normed,
# -> 2659         **({"data": data} if data is not None else {}), **kwargs)
#    2660
#    2661
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6589             # this will automatically overwrite bins,
#    6590             # so that each histogram uses the same bins
# -> 6591             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6592             m = m.astype(float)  # causes problems later if it's an int
#    6593             if mlast is None:
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     778     a, weights = _ravel_and_check_weights(a, weights)
#     779
# --> 780     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     781
#     782     # Histogram is an integer or a float array depending on the weights.
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     421         if np.any(bin_edges[:-1] > bin_edges[1:]):
#     422             raise ValueError(
# --> 423                 '`bins` must increase monotonically, when an array')
#     424
#     425     else:
#
# ValueError: `bins` must increase monotonically, when an array

# %% [markdown]
# # 15. Generate a 'joint plot' from seaborn between any two variable

# %%
sns.jointplot(advertising['sales'],advertising['radio'])
